# %%
#This is Question First of assignment 1.
#Using print() with multiple object

print("Harsh","Abhinav","Ankit","Rohit","Khevan","Bhavya","Keshul")
# Out:
# Harsh Abhinav Ankit Rohit Khevan Bhavya Keshul

# %%
#Using print() with separator and end.

print("Apple","Banana","Pineapple","Grapes","Orange","Mango.",sep="|",end="")
print("Fruits provide many health benefits.")
# Out:
# Apple|Banana|Pineapple|Grapes|Orange|Mango.Fruits provide many health benefits.

# %%
#This is Question Second of assignment 1.

username=input("Enter Your Name: ")
print(f"Welcome {username} We're excited to have you here and look forward to your contributions")
# Out:
# Welcome harsh We're excited to have you here and look forward to your contributions
