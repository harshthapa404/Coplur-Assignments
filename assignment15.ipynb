# %%
#Assignment 15 

#In this we have to add exception in assignment 13 Question
#This is Quesion 1 of assignment 13

try:
    class Temperature:
        def __init__(self,temp_in_celsius):
            self.temp_in_celsius=temp_in_celsius

        def to_fahrenheit(self):           
            print(f"\n {self.temp_in_celsius} Celsius into Fahrenheit : {(self.temp_in_celsius*1.8)+32} F")

        def to_kelvin(self):          
            print(f"\n {self.temp_in_celsius} Celsius into Kelvin : {self.temp_in_celsius + 273.15} K")


    f1=Temperature(25)      

    f1.to_fahrenheit()

    f1.to_kelvin()

except NameError:
    print("Check Your Code Spelling")
except TypeError:
    print("Operation can't perform because of different datatype")
except ValueError:
    print("Please enter valid number")
except AttributeError:
    print("Attribute or Method not found")
# Out:
#  25 Celsius into Fahrenheit : 77.0 F
#
#  25 Celsius into Kelvin : 298.15 K

# %%
#Assignment 15 

#In this we have to add exception in assignment 13 Question
#This is Quesion 2 of assignment 13

try:    
    import tkinter

    from tkinter import messagebox



    def simple_interest():
        principle=int(entry2.get())
        rate=int(entry3.get())
        time=int(entry4.get())
        print(f"\nSimple Interest : {(principle*rate*time)/100:.2f}")
        messagebox.showinfo("Interest Calculator","Calculation of Simple Interest done")



    def compound_interest():
        principle=int(e2.get())
        rate=int(e3.get())
        time=int(e4.get())
        n=int(e5.get())
        print(f"\nCompound Interest : {principle*(1+rate/100/n)**(time*n)-principle:.2f}")
        messagebox.showinfo("Interest Calculator","Calculation of Compound Interest done!!")




    root=tkinter.Tk()
    root.title("Interest Calculation")
    root.geometry("500x500")

    #Simple interest Calculation

    label1=tkinter.Label(root,text="Simple interest calculator",font=("Arial",15))
    label1.pack(pady=10)


    label2=tkinter.Label(root,text="Principle Amount",font=("Arial",10))
    label2.pack(pady=0)


    entry2=tkinter.Entry(root,width=10,font=("Arial",10))
    entry2.pack(pady=0)


    label3=tkinter.Label(root,text="Rate of Interest",font=("Arial",10))
    label3.pack(pady=0)


    entry3=tkinter.Entry(root,width=10,font=("Arial",10))
    entry3.pack(pady=0)


    label4=tkinter.Label(root,text="Time in Years",font=("Arial",10))
    label4.pack(pady=0)


    entry4=tkinter.Entry(root,width=10,font=("Arial",10))
    entry4.pack(pady=0)


    button1=tkinter.Button(root,text="Calculate Simple Interest",command=simple_interest,bg="white")
    button1.pack(pady=15)




    #Compound interest calculation




    l0=tkinter.Label(root,text="Compound Interest Calculator",font=("Arial",15))
    l0.pack(pady=10)


    l2=tkinter.Label(root,text="Principle Amount",font=("Arial",10))
    l2.pack(pady=0)


    e2=tkinter.Entry(root,width=10,font=("Arial",10))
    e2.pack(pady=0)


    l3=tkinter.Label(root,text="Rate of Interest",font=("Arial",10))
    l3.pack(pady=0)


    e3=tkinter.Entry(root,width=10,font=("Arial",10))
    e3.pack(pady=0)


    l4=tkinter.Label(root,text="Time in Years",font=("Arial",10))
    l4.pack(pady=0)


    e4=tkinter.Entry(root,width=10,font=("Arial",10))
    e4.pack(pady=0)


    l5=tkinter.Label(root,text="Interest Compounded Per Year in Numbers")
    l5.pack(pady=0)

    e5=tkinter.Entry(root,width=10,font=("Arial",10))
    e5.pack(pady=0)


    button2=tkinter.Button(root,text="Calculate Compound Interest",command=compound_interest,bg="white")
    button2.pack(pady=15)


    root.mainloop()


except NameError:
    print("Check Code Spelling")
except ValueError:
    print("Please enter Valid number")
except TypeError:
    print("Operation can't perform because of different datatype")
except AttributeError:
    print("Attribute or Method not found")

# %%
#Assignment 15 

#In this we have to add exception in assignment 13 Question
#This is Quesion 3 of assignment 13

try:
    class CoffeeMachine:

        def __init__(self,water,coffee,milk):
            self.water=water
            self.coffee=coffee
            self.milk=milk
        

        
        def make_latte(self):
            if (self.water>=200 and self.coffee>=20 and self.milk>=150):
                print("Yes, Latte coffee is available")
                self.water=self.water-200
                self.coffee=self.coffee-20
                self.milk=self.milk-150
            else:
                print("I apologize, but Latte coffee is currently unavailable")
        
        

        def display_latte_ingredients(self):
            print("\nRemaining Resources")
            print(f"Water(ml) : {self.water}")
            print(f"Coffee(g) : {self.coffee}")
            print(f"Milk(ml) : {self.milk}")

    coffee1=CoffeeMachine(300,30,200)   #Values of the water,coffee and milk.
    coffee1.make_latte()
    coffee1.display_latte_ingredients()

except NameError:
    print("Check Code Spelling")
except ValueError:
    print("Please enter Valid number")
except TypeError:
    print("Operation can't perform because of different datatype")
except AttributeError:
    print("Attribute or Method not found")
# Out:
# Yes, Latte coffee is available
#
# Remaining Resources
# Water(ml) : 100
# Coffee(g) : 10
# Milk(ml) : 50

# %%
#Assignment 15 

#In this we have to add exception in assignment 13 Question
#This is Quesion 4 of assignment 13

try:    
    class Vehicle:
        def __init__(self,name,max_speed):
            self.name=name
            self.max_speed=max_speed

        def display(self):
            print(f"Bus Name : {self.name}")
            print(f"Bus Max Speed : {self.max_speed}")

    class Bus(Vehicle):
        def __init__(self,name,max_speed,seats_booked,seating_capacity=50):
            self.name=name
            self.max_speed=max_speed
            self.seats_booked=seats_booked
            self.seating_capacity=seating_capacity

        def reservation(self):
            if (self.seating_capacity>=self.seats_booked):
                print(f"\nBus Booked Seats : {self.seats_booked}")
                print(f"Bus Seats Capacity : {self.seating_capacity}")
                print(f"\nYou can book {self.seats_booked} Seats because Bus Capacity is : {self.seating_capacity}")
            else:
                print(f"\nBus Seats Capacity : {self.seating_capacity}")
                print(f"You cannot book {self.seats_booked} Seats because Bus Capacity is : {self.seating_capacity}")
            



    obj1=Bus("Maha Laxmi",50,50)
    obj1.display()
    obj1.reservation()

except NameError:
    print("Check Code Spelling")
except ValueError:
    print("Please enter Valid number")
except TypeError:
    print("Operation can't perform because of different datatype")
except AttributeError:
    print("Attribute or Method not found")
# Out:
# Bus Name : Maha Laxmi
# Bus Max Speed : 50
# Attribute or Method not found
